# %%
import sys
sys.path.insert(0, "../source/")
sys.path.insert(0, "../models/AdvectionDiffusion_FEniCS")

import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg as la

from InverseProblem import InverseProblem
from FOM_stationary import FOM_stationary as FOM
from OEDUtility import OEDUtility

from MyDronePointEval import MyDronePointEval as DronePointEval
from MyDroneUniformEval import MyDroneUniformEval as DroneUniformEval
from MyDroneTruncGaussianEval import MyDroneTruncGaussianEval as DroneTruncGaussianEval
from MyDroneGaussianEval import MyDroneGaussianEval as DroneGaussianEval

import time
tStart_notebook = time.time()

import fenics as dl

import scipy.sparse as sparse
import scipy.sparse.linalg as sla

# %%
n_para = 5
var_prior = 1 # set to a high value (1e+6) to test convergence in noise-free situations

n_test = 40 # resolution for 1D plots
n_test_2d = 60 # resolution for 2D plots (50: ~1 min runtime for dt = 0.01)

sigma = 0.05
radius = 0.07

meshDim = 50
meshDim_drone = 10

bool_skip_2D_plots = True

# %%
tStart = time.time()
fom = FOM(meshDim = meshDim)
print("Runtime of this block: {} s".format(time.time()-tStart))

# compute one solution for nicer visualization below
#para_true = np.ones((n_para,))
para_true = np.zeros((n_para,))
para_true[0] = 1
state = fom.solve(parameter=para_true)
# Out:
# Runtime of this block: 1.7958719730377197 s

# %%
#     grad_1 = f'exp(-0.5 * ((x[0]-0)*((x[0]-0)) + (x[1]-0)*(x[1]-0)) / {4 * t * sigma**2}) * (-x[0]/({2 * t * sigma ** 2}))'
#     grad_2 = f'exp(-0.5 * ((x[0]-0)*((x[0]-0)) + (x[1]-0)*(x[1]-0)) / {4 * t * sigma**2}) * (-x[1]/({2 * t * sigma ** 2}))'
#     grad_1 = dl.Expression(grad_1, degree=1)
#     grad_2 = dl.Expression(grad_2, degree=1)
 #grad_Phi = dl.as_vector((grad_1, grad_2))

# %%
tStart = time.time()

# set diffusion coefficient to be the variance we want
diffusion = sigma ** 2

# choose the final time to bring the coefficient 1/(4*pi*D*t) into the form 1/(2*pi*sigma**2)
t_final = 0.5

# specify time discretization for heat equation
dt = 0.01
n_steps = int(t_final / dt)
# todo: evaluate how fine the time discretization actually needs to be

# initialize variables
u_old = state.state  # last time step
# note: I've double-checked that this initialization will not cause state.state to be changed by the code below
# (Nicole, Nov 21, 2023)

n = dl.FacetNormal(fom.mesh)
x = dl.SpatialCoordinate(fom.mesh)

for k in range(n_steps):
    u = dl.TrialFunction(fom.V)
    v = dl.TestFunction(fom.V)
    w = dl.Function(fom.V)

    t = (k+1) * dt

    tStart_sub = time.time()
    Phi = dl.exp(-((x[0]-0)*((x[0]-0)) + (x[1]-0)*(x[1]-0)) / (4 * t * sigma**2))
    
    grad_1 = -Phi * x[0] / (2 * t * sigma**2)
    grad_2 = -Phi * x[1] / (2 * t * sigma**2)
    grad_Phi = dl.as_vector((grad_1, grad_2))
    
    #g = dt * dl.inner(dl.inner(grad_Phi, n), v) * dl.ds + dl.inner(u_old, v) * dl.dx
#     g = dl.inner(dl.inner(dl.grad(Phi), n), v) * dl.ds + dl.inner(u_old, v) * dl.dx
    g = dl.inner(u_old, v) * dl.dx
    print("setup:", time.time()-tStart_sub)
    
    # Define variational form for the heat equation, implicit Euler
    F = dl.inner(u, v) * dl.dx \
        + dl.Constant(dt * diffusion) * dl.inner(dl.nabla_grad(u), dl.nabla_grad(v)) * dl.dx 

    # solve for next time step
    tStart_sub = time.time()
    problem = dl.LinearVariationalProblem(F, g, w)
    solver = dl.LinearVariationalSolver(problem)
    solver.solve()

    print("solve:", time.time()-tStart_sub)
    
    # we don't actually need to remember the whole trajectory, only the final state
    u_old = w
    
print("Runtime of this block: ", (time.time()-tStart)/60, "min.")
# Out:
# setup: 0.0006463527679443359
# solve: 0.028676986694335938
# setup: 0.0006709098815917969
# solve: 0.02628493309020996
# setup: 0.0005559921264648438
# solve: 0.023537158966064453
# setup: 0.0004780292510986328
# solve: 0.0221710205078125
# setup: 0.00048804283142089844
# solve: 0.02176213264465332
# setup: 0.00045680999755859375
# solve: 0.0221250057220459
# setup: 0.0004570484161376953
# solve: 0.0217440128326416
# setup: 0.0004680156707763672
# solve: 0.023806095123291016
# setup: 0.0006561279296875
# solve: 0.022882938385009766
# setup: 0.00047516822814941406
# solve: 0.021747112274169922
# setup: 0.0004608631134033203
# solve: 0.021810054779052734
# setup: 0.00045418739318847656
# solve: 0.022179841995239258
# setup: 0.0004608631134033203
# solve: 0.02395915985107422
# setup: 0.00047898292541503906
# solve: 0.02239990234375
# setup: 0.00047206878662109375
# solve: 0.021648883819580078
# setup: 0.000453948974609375
# solve: 0.02167201042175293
# setup: 0.0004429817199707031
# solve: 0.021979808807373047
# setup: 0.00045609474182128906
# solve: 0.021695852279663086
# setup: 0.0005159378051757812
# solve: 0.02230215072631836
# setup: 0.0004532337188720703
# solve: 0.02263498306274414
# setup: 0.0005347728729248047
# solve: 0.023326873779296875
# setup: 0.0006268024444580078
# solve: 0.021432161331176758
# setup: 0.0004448890686035156
# solve: 0.02161574363708496
# setup: 0.00045013427734375
# solve: 0.022829055786132812
# setup: 0.0005171298980712891
# solve: 0.022008895874023438
# setup: 0.00045490264892578125
# solve: 0.0216519832611084
# setup: 0.00044608116149902344
# solve: 0.021563291549682617
# setup: 0.0004467964172363281
# solve: 0.0221099853515625
# setup: 0.00045490264892578125
# solve: 0.02197575569152832
# setup: 0.0004439353942871094
# solve: 0.023295879364013672
# setup: 0.0004658699035644531
# solve: 0.02299809455871582
# setup: 0.0004839897155761719
# solve: 0.022016048431396484
# setup: 0.00045108795166015625
# solve: 0.02355194091796875
# setup: 0.0004699230194091797
# solve: 0.02174210548400879
# setup: 0.0004673004150390625
# solve: 0.02354717254638672
# setup: 0.0006656646728515625
# solve: 0.022429943084716797
# setup: 0.0005249977111816406
# solve: 0.022372007369995117
# setup: 0.00045490264892578125
# solve: 0.022169828414916992
# setup: 0.00045013427734375
# solve: 0.023457050323486328
# setup: 0.00047326087951660156
# solve: 0.021962881088256836
# setup: 0.000453948974609375
# solve: 0.02316904067993164
# setup: 0.0005710124969482422
# solve: 0.02256011962890625
# setup: 0.0004649162292480469
# solve: 0.022302865982055664
# setup: 0.0004611015319824219
# solve: 0.021519899368286133
# setup: 0.0004489421844482422
# solve: 0.023443222045898438
# setup: 0.0005419254302978516
# solve: 0.023123741149902344
# setup: 0.0004677772521972656
# solve: 0.021553993225097656
# setup: 0.00045680999755859375
# solve: 0.021970033645629883
# setup: 0.0004558563232421875
# solve: 0.02224588394165039
# setup: 0.0004611015319824219
# solve: 0.02162003517150879
# Runtime of this block:  0.020414984226226805 min.

# %%
fom.plot(u_old)

# %%
merk = u_old.copy()

# %% [markdown]
# Putting it into matrix-vector form to speed up computations:

# %%
tStart = time.time()

# set diffusion coefficient to be the variance we want
diffusion = sigma ** 2

# choose the final time to bring the coefficient 1/(4*pi*D*t) into the form 1/(2*pi*sigma**2)
t_final = 0.5

# specify time discretization for heat equation
dt = 0.01
n_steps = int(t_final / dt)
# todo: evaluate how fine the time discretization actually needs to be

# initialize variables
u_old = state.state  # last time step
u_old = u_old.vector().vec().array

n = dl.FacetNormal(fom.mesh)
y = fom.mesh.coordinates()
y = y[dl.dof_to_vertex_map(fom.V), :]

# precompute matrices for faster solve
u = dl.TrialFunction(fom.V)
v = dl.TestFunction(fom.V)
w = dl.Function(fom.V)

# variational form for the heat equation, implicit Euler
F = dl.inner(u, v) * dl.dx \
        + dl.Constant(dt * diffusion) * dl.inner(dl.nabla_grad(u), dl.nabla_grad(v)) * dl.dx 
A = dl.assemble(F)
A = dl.as_backend_type(A).mat()  # PETSc matrix
A = sparse.csr_matrix(A.getValuesCSR()[::-1], shape=A.size)
LU_solver = sparse.linalg.splu(sparse.csc_matrix(A))

# mass matrix
m = dl.inner(u, v) * dl.dx
M = dl.assemble(m)
M = dl.as_backend_type(M).mat()  # PETSc matrix
M = sparse.csr_matrix(M.getValuesCSR()[::-1], shape=M.size)

# Neumann boundary condition
g0 = dl.inner(dl.inner(u, n[0]), v) * dl.ds
g1 = dl.inner(dl.inner(u, n[1]), v) * dl.ds

G0 = dl.assemble(g0)
G0 = dl.as_backend_type(G0).mat()  # PETSc matrix
G0 = sparse.csr_matrix(G0.getValuesCSR()[::-1], shape=G0.size)

G1 = dl.assemble(g1)
G1 = dl.as_backend_type(G1).mat()  # PETSc matrix
G1 = sparse.csr_matrix(G1.getValuesCSR()[::-1], shape=G1.size)

for k in range(n_steps):
    
    # the Neumann bouncary conditions change in each time step
    t = (k+1) * dt

    tStart_sub = time.time()
    
#     phi = np.exp(-((y[:, 0]-0)*((y[:, 0]-0)) + (y[:, 1]-0)*(y[:, 1]-0)) / (4 * t * sigma**2))
#     # todo: is there / np.sqrt(4*np.pi*sigma**2*t) missing here?
#     grad_0 = -phi * y[:, 0] / (2 * t * sigma**2)
#     grad_1 = -phi * y[:, 1] / (2 * t * sigma**2)
    
#     # compute rhs
#     rhs = dt * G0 @ grad_0 + dt * G1 @ grad_1 + M @ u_old
    rhs = M @ u_old

    # solve for next time step
    tStart_sub = time.time()
    
    #w = sparse.linalg.spsolve(A, rhs)
    w = LU_solver.solve(rhs)
    print("solve:", time.time()-tStart_sub)
    # todo: use LU decomposition for more efficiency
    
    # we don't actually need to remember the whole trajectory, only the final state
    u_old = w
    
print("Runtime of this block: ", (time.time()-tStart)/60, "min.")
# Out:
# solve: 0.0009360313415527344
# solve: 0.0012710094451904297
# solve: 0.0008480548858642578
# solve: 0.0007297992706298828
# solve: 0.0018270015716552734
# solve: 0.002413034439086914
# solve: 0.0008630752563476562
# solve: 0.0008890628814697266
# solve: 0.0007519721984863281
# solve: 0.0006608963012695312
# solve: 0.0007522106170654297
# solve: 0.0005393028259277344
# solve: 0.0005130767822265625
# solve: 0.0005159378051757812
# solve: 0.0005350112915039062
# solve: 0.0005221366882324219
# solve: 0.0007128715515136719
# solve: 0.0008976459503173828
# solve: 0.0010061264038085938
# solve: 0.0028731822967529297
# solve: 0.0014698505401611328
# solve: 0.00107574462890625
# solve: 0.0011949539184570312
# solve: 0.0024988651275634766
# solve: 0.0008151531219482422
# solve: 0.0010166168212890625
# solve: 0.0026922225952148438
# solve: 0.0007348060607910156
# solve: 0.0008962154388427734
# solve: 0.0005750656127929688
# solve: 0.00131988525390625
# solve: 0.0016710758209228516
# solve: 0.0016429424285888672
# solve: 0.0007708072662353516
# solve: 0.0007297992706298828
# solve: 0.0007429122924804688
# solve: 0.0007658004760742188
# solve: 0.0007560253143310547
# solve: 0.0005991458892822266
# solve: 0.0006630420684814453
# solve: 0.0005629062652587891
# solve: 0.0005590915679931641
# solve: 0.0005588531494140625
# solve: 0.0005109310150146484
# solve: 0.0007119178771972656
# solve: 0.0006120204925537109
# solve: 0.00060272216796875
# solve: 0.0010259151458740234
# solve: 0.0010387897491455078
# solve: 0.0007660388946533203
# Runtime of this block:  0.0019236167271931967 min.

# %%
test = dl.Function(fom.V)
test.vector().vec().array = u_old

fom.plot(test)

# %%
fom.plot(state.state)

# %%
diff = merk.vector().vec().array - u_old

# %%
diff
# Out:
# array([1.77876919e-19, 1.79570985e-19, 1.93123512e-19, ...,
#        1.62630326e-17, 1.35525272e-17, 1.49619900e-17])

# %%
la.norm(diff, ord = np.infty)
# Out:
# 5.134781488891349e-16

# %% [markdown]
# **Welcome back!**
# Next steps:
# - check that the computed convolution is indeed correct
# - why are there negative values???

# %%
F = dl.inner(u, v) * dl.dx \
        + dl.Constant(dt * diffusion) * dl.inner(dl.nabla_grad(u), dl.nabla_grad(v)) * dl.dx 
A = dl.assemble(F)
A = dl.as_backend_type(A).mat()  # PETSc matrix

# %%
help(A)
# Out:
# Help on Mat object:
#
# class Mat(Object)
#  |  Method resolution order:
#  |      Mat
#  |      Object
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  PtAP(...)
#  |      Mat.PtAP(self, Mat P, Mat result=None, fill=None)
#  |
#  |  SOR(...)
#  |      Mat.SOR(self, Vec b, Vec x, omega=1.0, sortype=None, shift=0.0, its=1, lits=1)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __call__(self, /, *args, **kwargs)
#  |      Call self as a function.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __iadd__(self, value, /)
#  |      Return self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Return self*=value.
#  |
#  |  __isub__(self, value, /)
#  |      Return self-=value.
#  |
#  |  __itruediv__(self, value, /)
#  |      Return self/=value.
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __neg__(self, /)
#  |      -self
#  |
#  |  __pos__(self, /)
#  |      +self
#  |
#  |  __radd__(self, value, /)
#  |      Return value+self.
#  |
#  |  __rmul__(self, value, /)
#  |      Return value*self.
#  |
#  |  __rsub__(self, value, /)
#  |      Return value-self.
#  |
#  |  __rtruediv__(self, value, /)
#  |      Return value/self.
#  |
#  |  __setitem__(self, key, value, /)
#  |      Set self[key] to value.
#  |
#  |  __sub__(self, value, /)
#  |      Return self-value.
#  |
#  |  __truediv__(self, value, /)
#  |      Return self/value.
#  |
#  |  assemble(...)
#  |      Mat.assemble(self, assembly=None)
#  |
#  |  assemblyBegin(...)
#  |      Mat.assemblyBegin(self, assembly=None)
#  |
#  |  assemblyEnd(...)
#  |      Mat.assemblyEnd(self, assembly=None)
#  |
#  |  axpy(...)
#  |      Mat.axpy(self, alpha, Mat X, structure=None)
#  |
#  |  aypx(...)
#  |      Mat.aypx(self, alpha, Mat X, structure=None)
#  |
#  |  chop(...)
#  |      Mat.chop(self, tol)
#  |
#  |  conjugate(...)
#  |      Mat.conjugate(self, Mat out=None)
#  |
#  |  convert(...)
#  |      Mat.convert(self, mat_type=None, Mat out=None)
#  |
#  |  copy(...)
#  |      Mat.copy(self, Mat result=None, structure=None)
#  |
#  |  create(...)
#  |      Mat.create(self, comm=None)
#  |
#  |  createAIJ(...)
#  |      Mat.createAIJ(self, size, bsize=None, nnz=None, csr=None, comm=None)
#  |
#  |  createAIJCRL(...)
#  |      Mat.createAIJCRL(self, size, bsize=None, nnz=None, csr=None, comm=None)
#  |
#  |  createAIJWithArrays(...)
#  |      Mat.createAIJWithArrays(self, size, csr, bsize=None, comm=None)
#  |
#  |  createBAIJ(...)
#  |      Mat.createBAIJ(self, size, bsize, nnz=None, csr=None, comm=None)
#  |
#  |  createDense(...)
#  |      Mat.createDense(self, size, bsize=None, array=None, comm=None)
#  |
#  |  createH2OpusFromMat(...)
#  |      Mat.createH2OpusFromMat(self, Mat A, coordinates=None, dist=None, eta=None, leafsize=None, maxrank=None, bs=None, rtol=None)
#  |
#  |  createLRC(...)
#  |      Mat.createLRC(self, Mat A, Mat U, Vec c, Mat V)
#  |
#  |  createNest(...)
#  |      Mat.createNest(self, mats, isrows=None, iscols=None, comm=None)
#  |
#  |  createNormal(...)
#  |      Mat.createNormal(self, Mat mat)
#  |
#  |  createPython(...)
#  |      Mat.createPython(self, size, context=None, comm=None)
#  |
#  |  createSBAIJ(...)
#  |      Mat.createSBAIJ(self, size, bsize, nnz=None, csr=None, comm=None)
#  |
#  |  createScatter(...)
#  |      Mat.createScatter(self, Scatter scatter, comm=None)
#  |
#  |  createSubMatrices(...)
#  |      Mat.createSubMatrices(self, isrows, iscols=None, submats=None)
#  |
#  |  createSubMatrix(...)
#  |      Mat.createSubMatrix(self, IS isrow, IS iscol=None, Mat submat=None)
#  |
#  |  createSubMatrixVirtual(...)
#  |      Mat.createSubMatrixVirtual(self, Mat A, IS isrow, IS iscol=None)
#  |
#  |  createTranspose(...)
#  |      Mat.createTranspose(self, Mat mat)
#  |
#  |  createVecLeft(...)
#  |      Mat.createVecLeft(self)
#  |
#  |  createVecRight(...)
#  |      Mat.createVecRight(self)
#  |
#  |  createVecs(...)
#  |      Mat.createVecs(self, side=None)
#  |
#  |  destroy(...)
#  |      Mat.destroy(self)
#  |
#  |  diagonalScale(...)
#  |      Mat.diagonalScale(self, Vec L=None, Vec R=None)
#  |
#  |  duplicate(...)
#  |      Mat.duplicate(self, copy=False)
#  |
#  |  equal(...)
#  |      Mat.equal(self, Mat mat)
#  |
#  |  factorCholesky(...)
#  |      Mat.factorCholesky(self, IS isperm, options=None)
#  |
#  |  factorICC(...)
#  |      Mat.factorICC(self, IS isperm, options=None)
#  |
#  |  factorILU(...)
#  |      Mat.factorILU(self, IS isrow, IS iscol, options=None)
#  |
#  |  factorLU(...)
#  |      Mat.factorLU(self, IS isrow, IS iscol, options=None)
#  |
#  |  factorNumericCholesky(...)
#  |      Mat.factorNumericCholesky(self, Mat mat, options=None)
#  |
#  |  factorNumericLU(...)
#  |      Mat.factorNumericLU(self, Mat mat, options=None)
#  |
#  |  factorSymbolicCholesky(...)
#  |      Mat.factorSymbolicCholesky(self, IS isperm, options=None)
#  |
#  |  factorSymbolicICC(...)
#  |      Mat.factorSymbolicICC(self, IS isperm, options=None)
#  |
#  |  factorSymbolicILU(...)
#  |      Mat.factorSymbolicILU(self, IS isrow, IS iscol, options=None)
#  |
#  |  factorSymbolicLU(...)
#  |      Mat.factorSymbolicLU(self, Mat mat, IS isrow, IS iscol, options=None)
#  |
#  |  findZeroRows(...)
#  |      Mat.findZeroRows(self)
#  |
#  |  fixISLocalEmpty(...)
#  |      Mat.fixISLocalEmpty(self, fix)
#  |
#  |  getBlockSize(...)
#  |      Mat.getBlockSize(self)
#  |
#  |  getBlockSizes(...)
#  |      Mat.getBlockSizes(self)
#  |
#  |  getColumnIJ(...)
#  |      Mat.getColumnIJ(self, symmetric=False, compressed=False)
#  |
#  |  getColumnVector(...)
#  |      Mat.getColumnVector(self, column, Vec result=None)
#  |
#  |  getDM(...)
#  |      Mat.getDM(self)
#  |
#  |  getDenseArray(...)
#  |      Mat.getDenseArray(self)
#  |
#  |  getDenseLocalMatrix(...)
#  |      Mat.getDenseLocalMatrix(self)
#  |
#  |  getDiagonal(...)
#  |      Mat.getDiagonal(self, Vec result=None)
#  |
#  |  getDiagonalBlock(...)
#  |      Mat.getDiagonalBlock(self)
#  |
#  |  getISLocalMat(...)
#  |      Mat.getISLocalMat(self)
#  |
#  |  getInertia(...)
#  |      Mat.getInertia(self)
#  |
#  |  getInfo(...)
#  |      Mat.getInfo(self, info=None)
#  |
#  |  getLGMap(...)
#  |      Mat.getLGMap(self)
#  |
#  |  getLRCMats(...)
#  |      Mat.getLRCMats(self)
#  |
#  |  getLocalSize(...)
#  |      Mat.getLocalSize(self)
#  |
#  |  getLocalSubMatrix(...)
#  |      Mat.getLocalSubMatrix(self, IS isrow, IS iscol, Mat submat=None)
#  |
#  |  getMumpsCntl(...)
#  |      Mat.getMumpsCntl(self, icntl)
#  |
#  |  getMumpsIcntl(...)
#  |      Mat.getMumpsIcntl(self, icntl)
#  |
#  |  getMumpsInfo(...)
#  |      Mat.getMumpsInfo(self, icntl)
#  |
#  |  getMumpsInfog(...)
#  |      Mat.getMumpsInfog(self, icntl)
#  |
#  |  getMumpsRinfo(...)
#  |      Mat.getMumpsRinfo(self, icntl)
#  |
#  |  getMumpsRinfog(...)
#  |      Mat.getMumpsRinfog(self, icntl)
#  |
#  |  getNearNullSpace(...)
#  |      Mat.getNearNullSpace(self)
#  |
#  |  getNestISs(...)
#  |      Mat.getNestISs(self)
#  |
#  |  getNestLocalISs(...)
#  |      Mat.getNestLocalISs(self)
#  |
#  |  getNestSize(...)
#  |      Mat.getNestSize(self)
#  |
#  |  getNestSubMatrix(...)
#  |      Mat.getNestSubMatrix(self, i, j)
#  |
#  |  getNullSpace(...)
#  |      Mat.getNullSpace(self)
#  |
#  |  getOptionsPrefix(...)
#  |      Mat.getOptionsPrefix(self)
#  |
#  |  getOrdering(...)
#  |      Mat.getOrdering(self, ord_type)
#  |
#  |  getOwnershipIS(...)
#  |      Mat.getOwnershipIS(self)
#  |
#  |  getOwnershipRange(...)
#  |      Mat.getOwnershipRange(self)
#  |
#  |  getOwnershipRangeColumn(...)
#  |      Mat.getOwnershipRangeColumn(self)
#  |
#  |  getOwnershipRanges(...)
#  |      Mat.getOwnershipRanges(self)
#  |
#  |  getOwnershipRangesColumn(...)
#  |      Mat.getOwnershipRangesColumn(self)
#  |
#  |  getPythonContext(...)
#  |      Mat.getPythonContext(self)
#  |
#  |  getRedundantMatrix(...)
#  |      Mat.getRedundantMatrix(self, nsubcomm, subcomm=None, Mat out=None)
#  |
#  |  getRow(...)
#  |      Mat.getRow(self, row)
#  |
#  |  getRowIJ(...)
#  |      Mat.getRowIJ(self, symmetric=False, compressed=False)
#  |
#  |  getRowSum(...)
#  |      Mat.getRowSum(self, Vec result=None)
#  |
#  |  getSize(...)
#  |      Mat.getSize(self)
#  |
#  |  getSizes(...)
#  |      Mat.getSizes(self)
#  |
#  |  getTransposeNullSpace(...)
#  |      Mat.getTransposeNullSpace(self)
#  |
#  |  getType(...)
#  |      Mat.getType(self)
#  |
#  |  getValue(...)
#  |      Mat.getValue(self, row, col)
#  |
#  |  getValues(...)
#  |      Mat.getValues(self, rows, cols, values=None)
#  |
#  |  getValuesCSR(...)
#  |      Mat.getValuesCSR(self)
#  |
#  |  getVecLeft = createVecLeft(...)
#  |
#  |  getVecRight = createVecRight(...)
#  |
#  |  getVecs = createVecs(...)
#  |
#  |  hermitianTranspose(...)
#  |      Mat.hermitianTranspose(self, Mat out=None)
#  |
#  |  imagPart(...)
#  |      Mat.imagPart(self, Mat out=None)
#  |
#  |  increaseOverlap(...)
#  |      Mat.increaseOverlap(self, IS iset, overlap=1)
#  |
#  |  invertBlockDiagonal(...)
#  |      Mat.invertBlockDiagonal(self)
#  |
#  |  isAssembled(...)
#  |      Mat.isAssembled(self)
#  |
#  |  isHermitian(...)
#  |      Mat.isHermitian(self, tol=0)
#  |
#  |  isHermitianKnown(...)
#  |      Mat.isHermitianKnown(self)
#  |
#  |  isStructurallySymmetric(...)
#  |      Mat.isStructurallySymmetric(self)
#  |
#  |  isSymmetric(...)
#  |      Mat.isSymmetric(self, tol=0)
#  |
#  |  isSymmetricKnown(...)
#  |      Mat.isSymmetricKnown(self)
#  |
#  |  isTranspose(...)
#  |      Mat.isTranspose(self, Mat mat=None, tol=0)
#  |
#  |  kron(...)
#  |      Mat.kron(self, Mat mat, Mat result=None)
#  |
#  |  load(...)
#  |      Mat.load(self, Viewer viewer)
#  |
#  |  matMult(...)
#  |      Mat.matMult(self, Mat mat, Mat result=None, fill=None)
#  |
#  |  matSolve(...)
#  |      Mat.matSolve(self, Mat B, Mat X)
#  |
#  |  matTransposeMult(...)
#  |      Mat.matTransposeMult(self, Mat mat, Mat result=None, fill=None)
#  |
#  |  mult(...)
#  |      Mat.mult(self, Vec x, Vec y)
#  |
#  |  multAdd(...)
#  |      Mat.multAdd(self, Vec x, Vec v, Vec y)
#  |
#  |  multHermitian(...)
#  |      Mat.multHermitian(self, Vec x, Vec y)
#  |
#  |  multHermitianAdd(...)
#  |      Mat.multHermitianAdd(self, Vec x, Vec v, Vec y)
#  |
#  |  multTranspose(...)
#  |      Mat.multTranspose(self, Vec x, Vec y)
#  |
#  |  multTransposeAdd(...)
#  |      Mat.multTransposeAdd(self, Vec x, Vec v, Vec y)
#  |
#  |  norm(...)
#  |      Mat.norm(self, norm_type=None)
#  |
#  |  permute(...)
#  |      Mat.permute(self, IS row, IS col)
#  |
#  |  realPart(...)
#  |      Mat.realPart(self, Mat out=None)
#  |
#  |  reorderForNonzeroDiagonal(...)
#  |      Mat.reorderForNonzeroDiagonal(self, IS isrow, IS iscol, atol=0)
#  |
#  |  restoreISLocalMat(...)
#  |      Mat.restoreISLocalMat(self, Mat local)
#  |
#  |  restoreLocalSubMatrix(...)
#  |      Mat.restoreLocalSubMatrix(self, IS isrow, IS iscol, Mat submat)
#  |
#  |  retrieveValues(...)
#  |      Mat.retrieveValues(self)
#  |
#  |  scale(...)
#  |      Mat.scale(self, alpha)
#  |
#  |  setBlockSize(...)
#  |      Mat.setBlockSize(self, bsize)
#  |
#  |  setBlockSizes(...)
#  |      Mat.setBlockSizes(self, row_bsize, col_bsize)
#  |
#  |  setDM(...)
#  |      Mat.setDM(self, DM dm)
#  |
#  |  setDiagonal(...)
#  |      Mat.setDiagonal(self, Vec diag, addv=None)
#  |
#  |  setFromOptions(...)
#  |      Mat.setFromOptions(self)
#  |
#  |  setISLocalMat(...)
#  |      Mat.setISLocalMat(self, Mat local)
#  |
#  |  setISPreallocation(...)
#  |      Mat.setISPreallocation(self, nnz, onnz)
#  |
#  |  setLGMap(...)
#  |      Mat.setLGMap(self, LGMap rmap, LGMap cmap=None)
#  |
#  |  setMumpsCntl(...)
#  |      Mat.setMumpsCntl(self, icntl, val)
#  |
#  |  setMumpsIcntl(...)
#  |      Mat.setMumpsIcntl(self, icntl, ival)
#  |
#  |  setNearNullSpace(...)
#  |      Mat.setNearNullSpace(self, NullSpace nsp)
#  |
#  |  setNullSpace(...)
#  |      Mat.setNullSpace(self, NullSpace nsp)
#  |
#  |  setOption(...)
#  |      Mat.setOption(self, option, flag)
#  |
#  |  setOptionsPrefix(...)
#  |      Mat.setOptionsPrefix(self, prefix)
#  |
#  |  setPreallocationCSR(...)
#  |      Mat.setPreallocationCSR(self, csr)
#  |
#  |  setPreallocationDense(...)
#  |      Mat.setPreallocationDense(self, array)
#  |
#  |  setPreallocationNNZ(...)
#  |      Mat.setPreallocationNNZ(self, nnz)
#  |
#  |  setPythonContext(...)
#  |      Mat.setPythonContext(self, context)
#  |
#  |  setPythonType(...)
#  |      Mat.setPythonType(self, py_type)
#  |
#  |  setSizes(...)
#  |      Mat.setSizes(self, size, bsize=None)
#  |
#  |  setStencil(...)
#  |      Mat.setStencil(self, dims, starts=None, dof=1)
#  |
#  |  setTransposeNullSpace(...)
#  |      Mat.setTransposeNullSpace(self, NullSpace nsp)
#  |
#  |  setType(...)
#  |      Mat.setType(self, mat_type)
#  |
#  |  setUnfactored(...)
#  |      Mat.setUnfactored(self)
#  |
#  |  setUp(...)
#  |      Mat.setUp(self)
#  |
#  |  setValue(...)
#  |      Mat.setValue(self, row, col, value, addv=None)
#  |
#  |  setValueBlockedStagStencil(...)
#  |      Mat.setValueBlockedStagStencil(self, row, col, value, addv=None)
#  |
#  |  setValueBlockedStencil(...)
#  |      Mat.setValueBlockedStencil(self, row, col, value, addv=None)
#  |
#  |  setValueLocal(...)
#  |      Mat.setValueLocal(self, row, col, value, addv=None)
#  |
#  |  setValueStagStencil(...)
#  |      Mat.setValueStagStencil(self, row, col, value, addv=None)
#  |
#  |  setValueStencil(...)
#  |      Mat.setValueStencil(self, row, col, value, addv=None)
#  |
#  |  setValues(...)
#  |      Mat.setValues(self, rows, cols, values, addv=None)
#  |
#  |  setValuesBlocked(...)
#  |      Mat.setValuesBlocked(self, rows, cols, values, addv=None)
#  |
#  |  setValuesBlockedCSR(...)
#  |      Mat.setValuesBlockedCSR(self, I, J, V, addv=None)
#  |
#  |  setValuesBlockedIJV(...)
#  |      Mat.setValuesBlockedIJV(self, I, J, V, addv=None, rowmap=None)
#  |
#  |  setValuesBlockedLocal(...)
#  |      Mat.setValuesBlockedLocal(self, rows, cols, values, addv=None)
#  |
#  |  setValuesBlockedLocalCSR(...)
#  |      Mat.setValuesBlockedLocalCSR(self, I, J, V, addv=None)
#  |
#  |  setValuesBlockedLocalIJV(...)
#  |      Mat.setValuesBlockedLocalIJV(self, I, J, V, addv=None, rowmap=None)
#  |
#  |  setValuesBlockedLocalRCV(...)
#  |      Mat.setValuesBlockedLocalRCV(self, R, C, V, addv=None)
#  |
#  |  setValuesBlockedRCV(...)
#  |      Mat.setValuesBlockedRCV(self, R, C, V, addv=None)
#  |
#  |  setValuesCSR(...)
#  |      Mat.setValuesCSR(self, I, J, V, addv=None)
#  |
#  |  setValuesIJV(...)
#  |      Mat.setValuesIJV(self, I, J, V, addv=None, rowmap=None)
#  |
#  |  setValuesLocal(...)
#  |      Mat.setValuesLocal(self, rows, cols, values, addv=None)
#  |
#  |  setValuesLocalCSR(...)
#  |      Mat.setValuesLocalCSR(self, I, J, V, addv=None)
#  |
#  |  setValuesLocalIJV(...)
#  |      Mat.setValuesLocalIJV(self, I, J, V, addv=None, rowmap=None)
#  |
#  |  setValuesLocalRCV(...)
#  |      Mat.setValuesLocalRCV(self, R, C, V, addv=None)
#  |
#  |  setValuesRCV(...)
#  |      Mat.setValuesRCV(self, R, C, V, addv=None)
#  |
#  |  shift(...)
#  |      Mat.shift(self, alpha)
#  |
#  |  solve(...)
#  |      Mat.solve(self, Vec b, Vec x)
#  |
#  |  solveAdd(...)
#  |      Mat.solveAdd(self, Vec b, Vec y, Vec x)
#  |
#  |  solveBackward(...)
#  |      Mat.solveBackward(self, Vec b, Vec x)
#  |
#  |  solveForward(...)
#  |      Mat.solveForward(self, Vec b, Vec x)
#  |
#  |  solveTranspose(...)
#  |      Mat.solveTranspose(self, Vec b, Vec x)
#  |
#  |  solveTransposeAdd(...)
#  |      Mat.solveTransposeAdd(self, Vec b, Vec y, Vec x)
#  |
#  |  storeValues(...)
#  |      Mat.storeValues(self)
#  |
#  |  transpose(...)
#  |      Mat.transpose(self, Mat out=None)
#  |
#  |  transposeMatMult(...)
#  |      Mat.transposeMatMult(self, Mat mat, Mat result=None, fill=None)
#  |
#  |  view(...)
#  |      Mat.view(self, Viewer viewer=None)
#  |
#  |  zeroEntries(...)
#  |      Mat.zeroEntries(self)
#  |
#  |  zeroRows(...)
#  |      Mat.zeroRows(self, rows, diag=1, Vec x=None, Vec b=None)
#  |
#  |  zeroRowsColumns(...)
#  |      Mat.zeroRowsColumns(self, rows, diag=1, Vec x=None, Vec b=None)
#  |
#  |  zeroRowsColumnsLocal(...)
#  |      Mat.zeroRowsColumnsLocal(self, rows, diag=1, Vec x=None, Vec b=None)
#  |
#  |  zeroRowsColumnsStencil(...)
#  |      Mat.zeroRowsColumnsStencil(self, rows, diag=1, Vec x=None, Vec b=None)
#  |
#  |  zeroRowsLocal(...)
#  |      Mat.zeroRowsLocal(self, rows, diag=1, Vec x=None, Vec b=None)
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  assembled
#  |
#  |  block_size
#  |
#  |  block_sizes
#  |
#  |  hermitian
#  |
#  |  local_size
#  |
#  |  owner_range
#  |
#  |  owner_ranges
#  |
#  |  size
#  |
#  |  sizes
#  |
#  |  structsymm
#  |
#  |  symmetric
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  AssemblyType = <class 'petsc4py.PETSc.MatAssemblyType'>
#  |
#  |  FactorShiftType = <class 'petsc4py.PETSc.MatFactorShiftType'>
#  |
#  |  InfoType = <class 'petsc4py.PETSc.MatInfoType'>
#  |
#  |  Option = <class 'petsc4py.PETSc.MatOption'>
#  |
#  |  OrderingType = <class 'petsc4py.PETSc.MatOrderingType'>
#  |
#  |  SORType = <class 'petsc4py.PETSc.MatSORType'>
#  |
#  |  SolverType = <class 'petsc4py.PETSc.MatSolverType'>
#  |
#  |  Stencil = <class 'petsc4py.PETSc._Mat_Stencil'>
#  |
#  |  Structure = <class 'petsc4py.PETSc.MatStructure'>
#  |
#  |  Type = <class 'petsc4py.PETSc.MatType'>
#  |
#  |  __pyx_vtable__ = <capsule object NULL>
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from Object:
#  |
#  |  __bool__(self, /)
#  |      self != 0
#  |
#  |  __copy__(...)
#  |      Object.__copy__(self)
#  |
#  |  __deepcopy__(...)
#  |      Object.__deepcopy__(self, dict memo)
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  compose(...)
#  |      Object.compose(self, name, Object obj)
#  |
#  |  decRef(...)
#  |      Object.decRef(self)
#  |
#  |  getAttr(...)
#  |      Object.getAttr(self, name)
#  |
#  |  getClassId(...)
#  |      Object.getClassId(self)
#  |
#  |  getClassName(...)
#  |      Object.getClassName(self)
#  |
#  |  getComm(...)
#  |      Object.getComm(self)
#  |
#  |  getDict(...)
#  |      Object.getDict(self)
#  |
#  |  getName(...)
#  |      Object.getName(self)
#  |
#  |  getRefCount(...)
#  |      Object.getRefCount(self)
#  |
#  |  getTabLevel(...)
#  |      Object.getTabLevel(self)
#  |
#  |  incRef(...)
#  |      Object.incRef(self)
#  |
#  |  incrementTabLevel(...)
#  |      Object.incrementTabLevel(self, tab, Object parent=None)
#  |
#  |  query(...)
#  |      Object.query(self, name)
#  |
#  |  setAttr(...)
#  |      Object.setAttr(self, name, attr)
#  |
#  |  setName(...)
#  |      Object.setName(self, name)
#  |
#  |  setTabLevel(...)
#  |      Object.setTabLevel(self, level)
#  |
#  |  stateIncrease(...)
#  |      Object.stateIncrease(self)
#  |
#  |  viewFromOptions(...)
#  |      Object.viewFromOptions(self, name, Object prefix=None)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from Object:
#  |
#  |  classid
#  |
#  |  comm
#  |
#  |  fortran
#  |
#  |  handle
#  |
#  |  klass
#  |
#  |  name
#  |
#  |  prefix
#  |
#  |  refcount
#  |
#  |  type
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from Object:
#  |
#  |  __hash__ = None
